# %%
import pandas

# %%
df = pandas.read_csv("C:\\allowApps\\python\\apps\\python-mega-course\\python-mega-course\\22196_output.csv")
df
# Out:
#     Unnamed: 0                        Address   Area  Beds  Full Baths  \
# 0            0                      0 Gateway    NaN   NaN         NaN
# 1            1          1003 Winchester Blvd.    NaN   4.0         4.0
# 2            2                  600 Talladega  3,154   5.0         3.0
# 3            3             3239 Spearhead Way  3,076   4.0         3.0
# 4            4             522 Emerald Street  1,172   3.0         3.0
# 5            5           1302 Veteran's Drive  1,932   4.0         2.0
# 6            6               1021 Cypress Cir  1,676   4.0         3.0
# 7            7                 913 Madison Dr  1,344   3.0         2.0
# 8            8              1344 Teton Street  1,920   3.0         2.0
# 9            9                 4 Minnies Lane  1,664   3.0         2.0
# 10          10                  9339 Sd 26900  2,560   NaN         NaN
# 11          11               RR674P13 Hwy 377  2,000   NaN         NaN
# ...
